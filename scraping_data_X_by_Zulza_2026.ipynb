# %%
# 1. Hapus sisa konfigurasi repositori nodesource yang rusak agar tidak macet
# !sudo rm -f /etc/apt/sources.list.d/nodesource.list

# 2. Hapus total instalasi nodejs usang beserta konfigurasinya
# !sudo apt-get remove --purge nodejs npm -y
# !sudo apt-get autoremove -y
# !sudo apt-get update

# 3. Unduh dan jalankan skrip setup resmi NodeSource untuk Node.js v20 (LTS)
# !curl -fsSL https://nodesource.com | sudo -E bash -

# 4. Pasang Node.js v20 bersih beserta npm bawaannya yang kompatibel
# !sudo apt-get install -y nodejs

# 5. Sinkronisasi ulang variabel environment path Google Colab
# %env PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin

# 6. Validasi hasil (Harus memuat teks v20.x.x dan versi npm di atas v10)
# !node -v
# !npm -v
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package 'npm' is not installed, so not removed
# The following packages were automatically installed and are no longer required:
#   libc-ares2 libjs-highlight.js libnode72 nodejs-doc
# Use 'sudo apt autoremove' to remove them.
# The following packages will be REMOVED:
#   nodejs*
# 0 upgraded, 0 newly installed, 1 to remove and 66 not upgraded.
# After this operation, 929 kB disk space will be freed.
# (Reading database ... 124440 files and directories currently installed.)
# Removing nodejs (12.22.9~dfsg-1ubuntu3.6) ...
# Processing triggers for man-db (2.10.2-1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages will be REMOVED:
#   libc-ares2 libjs-highlight.js libnode72 nodejs-doc
# 0 upgraded, 0 newly installed, 4 to remove and 66 not upgraded.
# ...

# %%
# !npx --yes tweet-harvest@2.6.1 -s "Makan Bergizi Gratis" -l 2000 --token 518c2f55dfd40c4afa7bdc3880d403e59137e437 --tab LATEST --searchType Latest
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# error: unknown option '--searchType'
# ⠙

# %%
# %%bash
# # Memastikan sistem membaca Node.js v20 dari Conda
# export PATH=/usr/local/bin:$PATH
#
# # Jalankan crawling data Tweet-Harvest bersih tanpa parameter ilegal
# npx --yes tweet-harvest@2.6.1 -s "Makan Bergizi Gratis" -l 2000 --token 518c2f55dfd40c4afa7bdc3880d403e59137e437 --tab LATEST
# Out:
# Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Filling in keywords: Makan Bergizi Gratis
#
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Makan_Bergizi_Gratis_05-06-2026_03-05-30.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Makan_Bergizi_Gratis_05-06-2026_03-05-30.csv
# Total tweets saved: 40
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Makan_Bergizi_Gratis_05-06-2026_03-05-30.csv
# Total tweets saved: 60
#
# -- Scrolling... (1) (2)
#
# ...
